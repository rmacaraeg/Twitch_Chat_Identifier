# %%
server = 'irc.chat.twitch.tv'
port = 6667
nickname = 'datatestdummy' #username goes here
token = 'oauth:400o7hwm2fen32pwjigjpfi0cmixue' #oauth token goes here (include the oauth:)
channel = '#playhearthstone'
chat = 'playhearthstone_chat.log'

import socket

sock = socket.socket()

sock.connect((server, port))

sock.send(f"PASS {token}\n".encode('utf-8'))
sock.send(f"NICK {nickname}\n".encode('utf-8'))
sock.send(f"JOIN {channel}\n".encode('utf-8'))

resp = sock.recv(2048).decode('utf-8')

resp #run this cell twice

resp = sock.recv(2048).decode('utf-8')

resp #run this cell twice

import logging

logging.basicConfig(level=logging.DEBUG,
                    format='%(asctime)s — %(message)s',
                    datefmt='%Y-%m-%d_%H:%M:%S',
                    handlers=[logging.FileHandler(chat, encoding='utf-8')])

from emoji import demojize
import re
while True:
    resp = sock.recv(2048).decode('utf-8')

    if resp.startswith('PING'):
        sock.send("PONG\n".encode('utf-8'))
    
    elif len(resp) > 0:
#         logging.info(demojize(resp))
        msg = demojize(resp)

        _, _, message = re.search(':(.*)\!.*@.*\.tmi\.twitch\.tv PRIVMSG #(.*) :(.*)', msg).groups()
        print(message)

        
#you have to manually end this one or else it keeps running
# Out:
# casters <3
# ResidentSleeper
# no worries 4HEad
# world chamipon in RNGSTONE lul
# @PlayHearthstone Can you tell Kripp to start stream? FeelsBadMan
# What a pure and wholesome interview
# Yikes is this still going on? USA region seems to have the longest games
# Eddie the best
# PRChase PRChase
# Nalguidan win ?
# got spoiler: everyone dies
# Gg
# worst format ever
# This should have ended 3hs ago but warrior mirror is so much entertainment
# there were 2 people not playing warrior? POGGERS
# ResidentSleeper
# @batres2012 more class in Hearthstone? Really?
# @bejesuschrist spoilers
# warrior LUL
# D PogChamp F
# everything is warrior
# only 10 warriors.
# warrior in every match LUL
# Warriorstone
# Only 87% warrior FeelsOkayMan Clap
# What is this green on ETC? PogChamp?
# DOG Pog
# @sottle come back there probably won’t be warrior mirrors Kappa
# dog LUL
# warrior stone LUL
# G OMEGALUL T @zalaehs
# Warrior ResidentSleeper
# antmist warrior with dagger and warrior with spells SMOrc ?
# so i wonder if warrior's getting nerfed LUL
# tiring, exhausting, some fun OMEGALUL
# fun Kappa
# Finally over
# FUN LULW
# this is chess format
# Star DOESN'T kiss Marco on the last episode LUL
# 10/12
# :bell:
# @ZalaeHS beating up on justsaiyan FeelsBadMan
# 2 matches included not a warrior PogChamp PogChamp
# FUN EleGiggle
# now I get it
# D FrankerZ G Kreygasm <3
# fun OMEGALUL
# Rogue Warrior Warrior Warrior Mage Warrior
# Those casters are exhausted
# ban fatigue decks
# All non-warriors won
# omg this started before i went to sleep
# ResidentSleeper
# Lel
# If everyone's playing bomb warrior why noone teched against it?
# FUN Kappa
# @ZalaeHS 2020 spoiler, no thinks you're funny yet
# warrior vs warrior might as well be chess
# the finals will take place in the shadow realm i think
# T
# jesus christ, this stream is still going/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-fb327be8c30f> in <module>
#      34 import re
#      35 while True:
# ---> 36     resp = sock.recv(2048).decode('utf-8')
#      37
#      38     if resp.startswith('PING'):
#
# KeyboardInterrupt:
